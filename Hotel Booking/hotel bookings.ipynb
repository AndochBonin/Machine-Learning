# %%
from matplotlib import pyplot as plot

# %%
import numpy as np

# %%
import pandas as pd

# %%
document = pd.read_csv(r'C:\Users\bonin\Downloads\booking_of_hotel.csv')

# %%
df = pd.DataFrame(document)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
number_of_hotel_bookings = len(df.index)
print(number_of_hotel_bookings)
# Out:
# 119390

# %%
number_of_cancellations = len(df[df['is_canceled'] != 0])
print(number_of_cancellations)
# Out:
# 44224

# %%
number_of_noncancellations = len(df[df['is_canceled'] == 0])
print(number_of_noncancellations)
# Out:
# 75166

# %%
cancel_array = [number_of_cancellations, number_of_noncancellations]

# %%
plot.bar(["Cancelled", "Not Cancelled"], cancel_array)
plot.title("Cancellations Bar Chart")
# Out:
# Text(0.5, 1.0, 'Cancellations Bar Chart')

# %%
most_popular_month_of_arrival = df["arrival_date_month"].mode()
print(most_popular_month_of_arrival)
# Out:
# 0    August
# Name: arrival_date_month, dtype: object

# %%
#plot.hist(df["arrival_date_month"], rwidth=0.1)
df.plot()
# Out:
# <Axes: >

# %%
month_array = np.array(document.arrival_date_month)
month, count = np.unique(month_array, return_counts=True)

# %%
plot.bar(month, count, width=0.5)
# Out:
# <BarContainer object of 12 artists>

# %%
plot.pie(df["hotel"].value_counts(), labels=["City Hotel", "Resort Hotel"])
# Out:
# ([<matplotlib.patches.Wedge at 0x2698d521d80>,
# ...
#  [Text(-0.5433858480011854, 0.956416133381298, 'City Hotel'),
#   Text(0.5433858480011848, -0.9564161333812983, 'Resort Hotel')])

# %%
plot.pie(df["deposit_type"].value_counts(), labels=["Non Deposit", "No Refund", "Null"])
# Out:
# ([<matplotlib.patches.Wedge at 0x2698d690ee0>,
# ...
#  [Text(-1.0181924325401428, 0.4162741528343872, 'Non Deposit'),
#   Text(1.0164087119406244, -0.4206106635490841, 'No Refund'),
#   Text(1.0999900062128796, -0.004688947833933911, 'Null')])

# %%
plot.pie(df["country"].value_counts())
plot.title("Country distribution")
# Out:
# Text(0.5, 1.0, 'Country distribution')
